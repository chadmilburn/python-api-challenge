# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)


#print(weather_api_key)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#url
url = "http://api.openweathermap.org/data/2.5/weather?"
#api key loaded from api keys file
api_key = weather_api_key
temp_unit = "imperial"

# empty list to fill with API Call Data
name = []
lat = []
lon = []
max_temp = []
humidity = []
coludiness = []
wind_speed = []
country = []
date = []

# varibles for orginizing cities into sets of 50
records = 0
sets = 1


print('Beginning Data Retrieval')
print('---------------------------------------------------') 
# loop thorugh cities list to get weather data
for city in cities:
    #dynamic url from cities list
    new_url = (f'{url}appid={api_key}&units={temp_unit}&q={city}')
    #url response data in json format
    response = requests.get(new_url).json()
    #print(response)
    # organizing data in sets
    if records < 50:
         records = records + 1
    else:
         sets = sets + 1
         records = 0
    #print to watch loop work
    print(f'Processing {city} Record {records} of Set {sets} |')
    try:
        #create list for dataframe
        name.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        coludiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        #print(response)
    except KeyError:
        #if no city found print this
        print(f'{city} not found. Skipping------------------------------')
# Out:
# Beginning Data Retrieval
# ---------------------------------------------------
# Processing rameswaram Record 1 of Set 1 |
# Processing avarua Record 2 of Set 1 |
# Processing puerto ayora Record 3 of Set 1 |
# Processing port alfred Record 4 of Set 1 |
# Processing kalundborg Record 5 of Set 1 |
# Processing busselton Record 6 of Set 1 |
# Processing kruisfontein Record 7 of Set 1 |
# Processing rikitea Record 8 of Set 1 |
# Processing atuona Record 9 of Set 1 |
# Processing rawannawi Record 10 of Set 1 |
# rawannawi not found. Skipping------------------------------
# Processing izhma Record 11 of Set 1 |
# Processing chenghai Record 12 of Set 1 |
# Processing albany Record 13 of Set 1 |
# Processing punta arenas Record 14 of Set 1 |
# Processing emba Record 15 of Set 1 |
# Processing ushuaia Record 16 of Set 1 |
# Processing benguela Record 17 of Set 1 |
# Processing tuktoyaktuk Record 18 of Set 1 |
# Processing hobyo Record 19 of Set 1 |
# Processing bengkulu Record 20 of Set 1 |
# Processing guerrero negro Record 21 of Set 1 |
# Processing najran Record 22 of Set 1 |
# Processing taolanaro Record 23 of Set 1 |
# taolanaro not found. Skipping------------------------------
# Processing mataura Record 24 of Set 1 |
# Processing coquimbo Record 25 of Set 1 |
# Processing longyearbyen Record 26 of Set 1 |
# Processing kieta Record 27 of Set 1 |
# Processing leningradskiy Record 28 of Set 1 |
# Processing pisco Record 29 of Set 1 |
# Processing nanortalik Record 30 of Set 1 |
# Processing castro Record 31 of Set 1 |
# Processing tuy hoa Record 32 of Set 1 |
# Processing illoqqortoormiut Record 33 of Set 1 |
# illoqqortoormiut not found. Skipping------------------------------
# Processing umm kaddadah Record 34 of Set 1 |
# Processing jamestown Record 35 of Set 1 |
# Processing avera Record 36 of Set 1 |
# Processing thompson Record 37 of Set 1 |
# Processing vaini Record 38 of Set 1 |
# Processing hermanus Record 39 of Set 1 |
# Processing torbay Record 40 of Set 1 |
# Processing cape town Record 41 of Set 1 |
# Processing marcona Record 42 of Set 1 |
# marcona not found. Skipping------------------------------
# Processing barrow Record 43 of Set 1 |
# Processing yellowknife Record 44 of Set 1 |
# Processing khatanga Record 45 of Set 1 |
# Processing krasnoselkup Record 46 of Set 1 |
# Processing carnarvon Record 47 of Set 1 |
# Processing sinegorye Record 48 of Set 1 |
# Processing goma Record 49 of Set 1 |
# Processing college Record 50 of Set 1 |
# Processing karratha Record 0 of Set 2 |
# Processing richards bay Record 1 of Set 2 |
# Processing akranes Record 2 of Set 2 |
# Processing flinders Record 3 of Set 2 |
# Processing contamana Record 4 of Set 2 |
# Processing taburi Record 5 of Set 2 |
# taburi not found. Skipping------------------------------
# Processing mandera Record 6 of Set 2 |
# Processing kununurra Record 7 of Set 2 |
# Processing zeya Record 8 of Set 2 |
# Processing belle fourche Record 9 of Set 2 |
# Processing matara Record 10 of Set 2 |
# Processing viransehir Record 11 of Set 2 |
# Processing ahuimanu Record 12 of Set 2 |
# Processing rungata Record 13 of Set 2 |
# rungata not found. Skipping------------------------------
# Processing butaritari Record 14 of Set 2 |
# Processing fairbanks Record 15 of Set 2 |
# Processing new norfolk Record 16 of Set 2 |
# Processing moindou Record 17 of Set 2 |
# Processing vila velha Record 18 of Set 2 |
# Processing poum Record 19 of Set 2 |
# Processing bluff Record 20 of Set 2 |
# Processing urdzhar Record 21 of Set 2 |
# urdzhar not found. Skipping------------------------------
# Processing oriximina Record 22 of Set 2 |
# Processing port lincoln Record 23 of Set 2 |
# Processing georgetown Record 24 of Set 2 |
# Processing kahului Record 25 of Set 2 |
# Processing tasiilaq Record 26 of Set 2 |
# Processing okha Record 27 of Set 2 |
# Processing hilo Record 28 of Set 2 |
# Processing east london Record 29 of Set 2 |
# Processing sentyabrskiy Record 30 of Set 2 |
# sentyabrskiy not found. Skipping------------------------------
# Processing salalah Record 31 of Set 2 |
# Processing mys shmidta Record 32 of Set 2 |
# mys shmidta not found. Skipping------------------------------
# Processing san borja Record 33 of Set 2 |
# Processing talnakh Record 34 of Set 2 |
# Processing qaanaaq Record 35 of Set 2 |
# Processing nome Record 36 of Set 2 |
# Processing vao Record 37 of Set 2 |
# Processing mnogovershinnyy Record 38 of Set 2 |
# Processing gilazi Record 39 of Set 2 |
# gilazi not found. Skipping------------------------------
# Processing ishigaki Record 40 of Set 2 |
# Processing saint anthony Record 41 of Set 2 |
# Processing port elizabeth Record 42 of Set 2 |
# Processing tual Record 43 of Set 2 |
# Processing vila franca do campo Record 44 of Set 2 |
# Processing ionia Record 45 of Set 2 |
# Processing marevo Record 46 of Set 2 |
# Processing sorong Record 47 of Set 2 |
# Processing nikolskoye Record 48 of Set 2 |
# Processing fortuna Record 49 of Set 2 |
# Processing lingao Record 50 of Set 2 |
# Processing victoria Record 0 of Set 3 |
# Processing akot Record 1 of Set 3 |
# Processing kendari Record 2 of Set 3 |
# Processing narsaq Record 3 of Set 3 |
# Processing laguna Record 4 of Set 3 |
# Processing mocuba Record 5 of Set 3 |
# Processing maine-soroa Record 6 of Set 3 |
# Processing ler Record 7 of Set 3 |
# Processing bucerias Record 8 of Set 3 |
# Processing starotimoshkino Record 9 of Set 3 |
# Processing barentsburg Record 10 of Set 3 |
# barentsburg not found. Skipping------------------------------
# Processing saint-augustin Record 11 of Set 3 |
# Processing yar-sale Record 12 of Set 3 |
# Processing mandalgovi Record 13 of Set 3 |
# Processing manaure Record 14 of Set 3 |
# Processing te anau Record 15 of Set 3 |
# Processing north bend Record 16 of Set 3 |
# Processing lolua Record 17 of Set 3 |
# lolua not found. Skipping------------------------------
# Processing plettenberg bay Record 18 of Set 3 |
# Processing walvis bay Record 19 of Set 3 |
# Processing saint-philippe Record 20 of Set 3 |
# Processing iqaluit Record 21 of Set 3 |
# Processing san matias Record 22 of Set 3 |
# Processing leiyang Record 23 of Set 3 |
# Processing faanui Record 24 of Set 3 |
# Processing oranjemund Record 25 of Set 3 |
# Processing bustonkala Record 26 of Set 3 |
# bustonkala not found. Skipping------------------------------
# Processing botwood Record 27 of Set 3 |
# Processing feodosiya Record 28 of Set 3 |
# Processing verkhoyansk Record 29 of Set 3 |
# Processing moranbah Record 30 of Set 3 |
# Processing florence Record 31 of Set 3 |
# Processing concarneau Record 32 of Set 3 |
# Processing hamilton Record 33 of Set 3 |
# Processing urengoy Record 34 of Set 3 |
# Processing bredasdorp Record 35 of Set 3 |
# Processing saskylakh Record 36 of Set 3 |
# Processing port macquarie Record 37 of Set 3 |
# Processing kaeo Record 38 of Set 3 |
# Processing umzimvubu Record 39 of Set 3 |
# umzimvubu not found. Skipping------------------------------
# Processing kapaa Record 40 of Set 3 |
# Processing hobart Record 41 of Set 3 |
# Processing hithadhoo Record 42 of Set 3 |
# Processing ancud Record 43 of Set 3 |
# Processing kushmurun Record 44 of Set 3 |
# Processing porbandar Record 45 of Set 3 |
# Processing bushehr Record 46 of Set 3 |
# Processing clyde river Record 47 of Set 3 |
# Processing santa cruz cabralia Record 48 of Set 3 |
# Processing bogorodskoye Record 49 of Set 3 |
# Processing san cristobal Record 50 of Set 3 |
# Processing dunedin Record 0 of Set 4 |
# Processing tawkar Record 1 of Set 4 |
# tawkar not found. Skipping------------------------------
# Processing kazalinsk Record 2 of Set 4 |
# kazalinsk not found. Skipping------------------------------
# Processing northam Record 3 of Set 4 |
# Processing margate Record 4 of Set 4 |
# Processing ostrovnoy Record 5 of Set 4 |
# Processing pacific grove Record 6 of Set 4 |
# Processing malanje Record 7 of Set 4 |
# Processing tabiauea Record 8 of Set 4 |
# tabiauea not found. Skipping------------------------------
# Processing chokurdakh Record 9 of Set 4 |
# Processing dikson Record 10 of Set 4 |
# Processing jijiga Record 11 of Set 4 |
# Processing vanavara Record 12 of Set 4 |
# Processing ribeira grande Record 13 of Set 4 |
# Processing senneterre Record 14 of Set 4 |
# Processing lasa Record 15 of Set 4 |
# Processing ushtobe Record 16 of Set 4 |
# Processing tabukiniberu Record 17 of Set 4 |
# tabukiniberu not found. Skipping------------------------------
# Processing kodiak Record 18 of Set 4 |
# Processing attawapiskat Record 19 of Set 4 |
# attawapiskat not found. Skipping------------------------------
# Processing saravena Record 20 of Set 4 |
# Processing harrisonburg Record 21 of Set 4 |
# Processing altay Record 22 of Set 4 |
# Processing uray Record 23 of Set 4 |
# Processing saint george Record 24 of Set 4 |
# Processing ajdabiya Record 25 of Set 4 |
# Processing soyo Record 26 of Set 4 |
# Processing gaoua Record 27 of Set 4 |
# Processing davila Record 28 of Set 4 |
# Processing tiksi Record 29 of Set 4 |
# Processing jiuquan Record 30 of Set 4 |
# Processing tamasopo Record 31 of Set 4 |
# Processing portland Record 32 of Set 4 |
# Processing cap malheureux Record 33 of Set 4 |
# Processing sooke Record 34 of Set 4 |
# Processing alofi Record 35 of Set 4 |
# Processing pangai Record 36 of Set 4 |
# Processing baykit Record 37 of Set 4 |
# Processing makakilo city Record 38 of Set 4 |
# Processing stonewall Record 39 of Set 4 |
# Processing quelimane Record 40 of Set 4 |
# Processing nizhniy odes Record 41 of Set 4 |
# Processing kaitangata Record 42 of Set 4 |
# Processing svetlaya Record 43 of Set 4 |
# Processing cockburn town Record 44 of Set 4 |
# Processing tartagal Record 45 of Set 4 |
# Processing severo-kurilsk Record 46 of Set 4 |
# Processing sibolga Record 47 of Set 4 |
# Processing bambous virieux Record 48 of Set 4 |
# Processing asau Record 49 of Set 4 |
# Processing maykain Record 50 of Set 4 |
# maykain not found. Skipping------------------------------
# Processing teya Record 0 of Set 5 |
# Processing berlevag Record 1 of Set 5 |
# Processing puerto carreno Record 2 of Set 5 |
# Processing presidente epitacio Record 3 of Set 5 |
# Processing palana Record 4 of Set 5 |
# Processing la palma Record 5 of Set 5 |
# Processing okhotsk Record 6 of Set 5 |
# Processing mao Record 7 of Set 5 |
# Processing aklavik Record 8 of Set 5 |
# Processing turbat Record 9 of Set 5 |
# Processing kapoeta Record 10 of Set 5 |
# Processing eyl Record 11 of Set 5 |
# Processing chuzhou Record 12 of Set 5 |
# Processing klaksvik Record 13 of Set 5 |
# Processing souillac Record 14 of Set 5 |
# Processing zachagansk Record 15 of Set 5 |
# zachagansk not found. Skipping------------------------------
# Processing vostok Record 16 of Set 5 |
# Processing chuy Record 17 of Set 5 |
# Processing cumberland Record 18 of Set 5 |
# Processing saldanha Record 19 of Set 5 |
# Processing amderma Record 20 of Set 5 |
# amderma not found. Skipping------------------------------
# Processing umba Record 21 of Set 5 |
# Processing kenai Record 22 of Set 5 |
# Processing alikovo Record 23 of Set 5 |
# Processing ahtopol Record 24 of Set 5 |
# Processing miraflores Record 25 of Set 5 |
# Processing airai Record 26 of Set 5 |
# Processing jumla Record 27 of Set 5 |
# Processing broome Record 28 of Set 5 |
# Processing alotau Record 29 of Set 5 |
# alotau not found. Skipping------------------------------
# Processing salinas Record 30 of Set 5 |
# Processing havre-saint-pierre Record 31 of Set 5 |
# Processing sao joao da barra Record 32 of Set 5 |
# Processing kothapet Record 33 of Set 5 |
# Processing iquique Record 34 of Set 5 |
# Processing sioux lookout Record 35 of Set 5 |
# Processing lagoa Record 36 of Set 5 |
# Processing sjovegan Record 37 of Set 5 |
# Processing belushya guba Record 38 of Set 5 |
# belushya guba not found. Skipping------------------------------
# Processing henties bay Record 39 of Set 5 |
# Processing shingu Record 40 of Set 5 |
# Processing iglino Record 41 of Set 5 |
# Processing gap Record 42 of Set 5 |
# Processing kamaishi Record 43 of Set 5 |
# Processing vila Record 44 of Set 5 |
# Processing thinadhoo Record 45 of Set 5 |
# Processing wad rawah Record 46 of Set 5 |
# Processing kaili Record 47 of Set 5 |
# Processing pareora Record 48 of Set 5 |
# Processing khormuj Record 49 of Set 5 |
# khormuj not found. Skipping------------------------------
# Processing san patricio Record 50 of Set 5 |
# Processing inirida Record 0 of Set 6 |
# Processing labuhan Record 1 of Set 6 |
# Processing ilulissat Record 2 of Set 6 |
# Processing oum hadjer Record 3 of Set 6 |
# Processing tunduru Record 4 of Set 6 |
# tunduru not found. Skipping------------------------------
# Processing gravdal Record 5 of Set 6 |
# Processing vaitape Record 6 of Set 6 |
# Processing hasaki Record 7 of Set 6 |
# Processing sao filipe Record 8 of Set 6 |
# Processing cloppenburg Record 9 of Set 6 |
# Processing barcelos Record 10 of Set 6 |
# Processing nizhneangarsk Record 11 of Set 6 |
# Processing awjilah Record 12 of Set 6 |
# Processing aykhal Record 13 of Set 6 |
# Processing chulym Record 14 of Set 6 |
# Processing lebu Record 15 of Set 6 |
# Processing tamalin Record 16 of Set 6 |
# Processing muzaffarabad Record 17 of Set 6 |
# Processing oistins Record 18 of Set 6 |
# Processing chara Record 19 of Set 6 |
# Processing yima Record 20 of Set 6 |
# Processing vaitupu Record 21 of Set 6 |
# vaitupu not found. Skipping------------------------------
# Processing nizhneyansk Record 22 of Set 6 |
# nizhneyansk not found. Skipping------------------------------
# Processing tanout Record 23 of Set 6 |
# Processing mitsamiouli Record 24 of Set 6 |
# Processing mahebourg Record 25 of Set 6 |
# Processing burica Record 26 of Set 6 |
# burica not found. Skipping------------------------------
# Processing touros Record 27 of Set 6 |
# Processing los llanos de aridane Record 28 of Set 6 |
# Processing barstow Record 29 of Set 6 |
# Processing codrington Record 30 of Set 6 |
# Processing palmer Record 31 of Set 6 |
# Processing bethel Record 32 of Set 6 |
# Processing ponta do sol Record 33 of Set 6 |
# Processing palocabildo Record 34 of Set 6 |
# Processing tepla Record 35 of Set 6 |
# Processing honiara Record 36 of Set 6 |
# Processing sovetskiy Record 37 of Set 6 |
# Processing kerteh Record 38 of Set 6 |
# kerteh not found. Skipping------------------------------
# Processing prince rupert Record 39 of Set 6 |
# Processing cabo san lucas Record 40 of Set 6 |
# Processing mino Record 41 of Set 6 |
# Processing broken hill Record 42 of Set 6 |
# Processing anyang Record 43 of Set 6 |
# Processing samalaeulu Record 44 of Set 6 |
# samalaeulu not found. Skipping------------------------------
# Processing isoka Record 45 of Set 6 |
# Processing caucaia Record 46 of Set 6 |
# Processing dingle Record 47 of Set 6 |
# Processing saleaula Record 48 of Set 6 |
# saleaula not found. Skipping------------------------------
# Processing prado Record 49 of Set 6 |
# Processing lompoc Record 50 of Set 6 |
# Processing pevek Record 0 of Set 7 |
# Processing noumea Record 1 of Set 7 |
# Processing floro Record 2 of Set 7 |
# Processing karistos Record 3 of Set 7 |
# karistos not found. Skipping------------------------------
# Processing severo-yeniseyskiy Record 4 of Set 7 |
# Processing pleshanovo Record 5 of Set 7 |
# Processing luderitz Record 6 of Set 7 |
# Processing felidhoo Record 7 of Set 7 |
# felidhoo not found. Skipping------------------------------
# Processing sao felix do xingu Record 8 of Set 7 |
# Processing katsuura Record 9 of Set 7 |
# Processing velyka bahachka Record 10 of Set 7 |
# Processing petropavlovsk-kamchatskiy Record 11 of Set 7 |
# Processing hun Record 12 of Set 7 |
# Processing waynesville Record 13 of Set 7 |
# Processing chinhoyi Record 14 of Set 7 |
# Processing ahipara Record 15 of Set 7 |
# Processing middlebury Record 16 of Set 7 |
# Processing belfast Record 17 of Set 7 |
# Processing hronov Record 18 of Set 7 |
# Processing maningrida Record 19 of Set 7 |
# Processing moerai Record 20 of Set 7 |
# Processing pointe-noire Record 21 of Set 7 |
# Processing mar del plata Record 22 of Set 7 |
# Processing patea Record 23 of Set 7 |
# Processing martaban Record 24 of Set 7 |
# Processing tabuk Record 25 of Set 7 |
# Processing schrobenhausen Record 26 of Set 7 |
# Processing luwuk Record 27 of Set 7 |
# Processing remuna Record 28 of Set 7 |
# Processing conner Record 29 of Set 7 |
# Processing ust-kamchatsk Record 30 of Set 7 |
# ust-kamchatsk not found. Skipping------------------------------
# Processing farah Record 31 of Set 7 |
# Processing tura Record 32 of Set 7 |
# Processing toba tek singh Record 33 of Set 7 |
# Processing taltal Record 34 of Set 7 |
# Processing aktau Record 35 of Set 7 |
# Processing muros Record 36 of Set 7 |
# Processing sinnamary Record 37 of Set 7 |
# Processing ulladulla Record 38 of Set 7 |
# Processing terrace Record 39 of Set 7 |
# Processing kavieng Record 40 of Set 7 |
# Processing upernavik Record 41 of Set 7 |
# Processing srednekolymsk Record 42 of Set 7 |
# Processing meulaboh Record 43 of Set 7 |
# Processing harper Record 44 of Set 7 |
# Processing andevoranto Record 45 of Set 7 |
# andevoranto not found. Skipping------------------------------
# Processing hofn Record 46 of Set 7 |
# Processing grindavik Record 47 of Set 7 |
# Processing yamada Record 48 of Set 7 |
# Processing adrar Record 49 of Set 7 |
# Processing yumen Record 50 of Set 7 |
# Processing geresk Record 0 of Set 8 |
# geresk not found. Skipping------------------------------
# Processing half moon bay Record 1 of Set 8 |
# Processing sitka Record 2 of Set 8 |
# Processing lamego Record 3 of Set 8 |
# Processing kulhudhuffushi Record 4 of Set 8 |
# Processing bereda Record 5 of Set 8 |
# Processing namatanai Record 6 of Set 8 |
# Processing tuatapere Record 7 of Set 8 |
# Processing maicao Record 8 of Set 8 |
# Processing cidreira Record 9 of Set 8 |
# Processing tilichiki Record 10 of Set 8 |
# Processing port-cartier Record 11 of Set 8 |
# Processing goderich Record 12 of Set 8 |
# Processing mount isa Record 13 of Set 8 |
# Processing beringovskiy Record 14 of Set 8 |
# Processing dahra Record 15 of Set 8 |
# Processing provideniya Record 16 of Set 8 |
# Processing irbeyskoye Record 17 of Set 8 |
# Processing verkhnyaya inta Record 18 of Set 8 |
# Processing gorom-gorom Record 19 of Set 8 |
# Processing evensk Record 20 of Set 8 |
# Processing ponta grossa Record 21 of Set 8 |
# Processing leh Record 22 of Set 8 |
# Processing mishelevka Record 23 of Set 8 |
# Processing bathsheba Record 24 of Set 8 |
# Processing contai Record 25 of Set 8 |
# Processing douentza Record 26 of Set 8 |
# Processing samarai Record 27 of Set 8 |
# Processing kousseri Record 28 of Set 8 |
# Processing zunyi Record 29 of Set 8 |
# Processing provost Record 30 of Set 8 |
# Processing whitecourt Record 31 of Set 8 |
# Processing mareeba Record 32 of Set 8 |
# Processing padang Record 33 of Set 8 |
# Processing comodoro rivadavia Record 34 of Set 8 |
# Processing luganville Record 35 of Set 8 |
# Processing cheuskiny Record 36 of Set 8 |
# cheuskiny not found. Skipping------------------------------
# Processing constitucion Record 37 of Set 8 |
# Processing afmadu Record 38 of Set 8 |
# afmadu not found. Skipping------------------------------
# Processing the valley Record 39 of Set 8 |
# Processing buraydah Record 40 of Set 8 |
# Processing coihaique Record 41 of Set 8 |
# Processing gat Record 42 of Set 8 |
# Processing yaypan Record 43 of Set 8 |
# Processing graham Record 44 of Set 8 |
# Processing esperance Record 45 of Set 8 |
# Processing acapulco Record 46 of Set 8 |
# Processing mehamn Record 47 of Set 8 |
# Processing anloga Record 48 of Set 8 |
# Processing port alberni Record 49 of Set 8 |
# Processing stoyba Record 50 of Set 8 |
# stoyba not found. Skipping------------------------------
# Processing bud Record 0 of Set 9 |
# Processing waipawa Record 1 of Set 9 |
# Processing yuli Record 2 of Set 9 |
# Processing chichli Record 3 of Set 9 |
# Processing armacao dos buzios Record 4 of Set 9 |
# armacao dos buzios not found. Skipping------------------------------
# Processing rio gallegos Record 5 of Set 9 |
# Processing sambava Record 6 of Set 9 |
# Processing bontang Record 7 of Set 9 |
# Processing tiarei Record 8 of Set 9 |
# Processing aranos Record 9 of Set 9 |
# Processing hay river Record 10 of Set 9 |
# Processing oslomej Record 11 of Set 9 |
# Processing nelson bay Record 12 of Set 9 |
# Processing maua Record 13 of Set 9 |
# Processing vestmanna Record 14 of Set 9 |
# Processing alice springs Record 15 of Set 9 |
# Processing norman wells Record 16 of Set 9 |
# Processing severnoye Record 17 of Set 9 |
# Processing ballina Record 18 of Set 9 |
# Processing nishihara Record 19 of Set 9 |
# Processing mayo Record 20 of Set 9 |
# Processing saint-pierre Record 21 of Set 9 |
# Processing marienburg Record 22 of Set 9 |
# Processing roebourne Record 23 of Set 9 |
# Processing karpathos Record 24 of Set 9 |
# Processing prachuap khiri khan Record 25 of Set 9 |
# Processing naze Record 26 of Set 9 |
# Processing anisoc Record 27 of Set 9 |
# Processing truth or consequences Record 28 of Set 9 |
# Processing shimoda Record 29 of Set 9 |
# Processing umm lajj Record 30 of Set 9 |
# Processing banfora Record 31 of Set 9 |
# Processing antofagasta Record 32 of Set 9 |
# Processing dolinsk Record 33 of Set 9 |
# Processing buritis Record 34 of Set 9 |
# Processing yerbogachen Record 35 of Set 9 |
# Processing bilma Record 36 of Set 9 |
# Processing shaowu Record 37 of Set 9 |
# Processing xuddur Record 38 of Set 9 |
# Processing shebunino Record 39 of Set 9 |
# Processing mosquera Record 40 of Set 9 |
# Processing tautira Record 41 of Set 9 |
# Processing mantua Record 42 of Set 9 |
# Processing tuzla Record 43 of Set 9 |
# Processing elizabeth city Record 44 of Set 9 |
# Processing vestmannaeyjar Record 45 of Set 9 |
# Processing roma Record 46 of Set 9 |
# Processing aswan Record 47 of Set 9 |
# Processing kharp Record 48 of Set 9 |
# Processing santa isabel do rio negro Record 49 of Set 9 |
# Processing dalbandin Record 50 of Set 9 |
# Processing obama Record 0 of Set 10 |
# Processing kudahuvadhoo Record 1 of Set 10 |
# Processing chauk Record 2 of Set 10 |
# Processing clarence town Record 3 of Set 10 |
# Processing hualmay Record 4 of Set 10 |
# Processing ucluelet Record 5 of Set 10 |
# Processing galveston Record 6 of Set 10 |
# Processing buala Record 7 of Set 10 |
# Processing grand river south east Record 8 of Set 10 |
# grand river south east not found. Skipping------------------------------
# Processing rocha Record 9 of Set 10 |
# Processing jambol Record 10 of Set 10 |
# jambol not found. Skipping------------------------------
# Processing arraial do cabo Record 11 of Set 10 |
# Processing mukhen Record 12 of Set 10 |
# Processing yaan Record 13 of Set 10 |
# Processing manokwari Record 14 of Set 10 |
# Processing tevriz Record 15 of Set 10 |
# Processing abu kamal Record 16 of Set 10 |
# Processing sorland Record 17 of Set 10 |
# Processing cunha Record 18 of Set 10 |
# Processing faya Record 19 of Set 10 |
# Processing tarpon springs Record 20 of Set 10 |
# Processing halalo Record 21 of Set 10 |
# halalo not found. Skipping------------------------------
# Processing tukrah Record 22 of Set 10 |
# Processing komsomolskiy Record 23 of Set 10 |
# Processing hirara Record 24 of Set 10 |
# Processing tarko-sale Record 25 of Set 10 |
# Processing agadez Record 26 of Set 10 |
# Processing tongliao Record 27 of Set 10 |
# Processing mugan Record 28 of Set 10 |
# Processing mount gambier Record 29 of Set 10 |
# Processing ituni Record 30 of Set 10 |
# ituni not found. Skipping------------------------------
# Processing uitenhage Record 31 of Set 10 |
# Processing tete Record 32 of Set 10 |
# Processing karaul Record 33 of Set 10 |
# karaul not found. Skipping------------------------------
# Processing zabol Record 34 of Set 10 |
# Processing san ignacio Record 35 of Set 10 |
# Processing vicuna Record 36 of Set 10 |
# Processing nizwa Record 37 of Set 10 |
# Processing port blair Record 38 of Set 10 |
# Processing cassia Record 39 of Set 10 |
# Processing lorengau Record 40 of Set 10 |
# Processing vardo Record 41 of Set 10 |
# Processing praia da vitoria Record 42 of Set 10 |
# Processing paramirim Record 43 of Set 10 |
# Processing vikhorevka Record 44 of Set 10 |
# Processing tigzirt Record 45 of Set 10 |
# Processing bolonchen Record 46 of Set 10 |
# bolonchen not found. Skipping------------------------------
# Processing sholavandan Record 47 of Set 10 |
# sholavandan not found. Skipping------------------------------
# Processing amarante do maranhao Record 48 of Set 10 |
# Processing spearfish Record 49 of Set 10 |
# Processing liverpool Record 50 of Set 10 |
# Processing praya Record 0 of Set 11 |
# Processing kitakata Record 1 of Set 11 |
# Processing katobu Record 2 of Set 11 |
# Processing general pico Record 3 of Set 11 |
# Processing angra Record 4 of Set 11 |
# angra not found. Skipping------------------------------
# Processing catamarca Record 5 of Set 11 |
# Processing praia Record 6 of Set 11 |
# Processing kishangarh Record 7 of Set 11 |
# Processing tabialan Record 8 of Set 11 |
# tabialan not found. Skipping------------------------------
# Processing monte alegre Record 9 of Set 11 |
# Processing amalapuram Record 10 of Set 11 |
# Processing luena Record 11 of Set 11 |
# Processing bad windsheim Record 12 of Set 11 |
# Processing neijiang Record 13 of Set 11 |
# Processing silver city Record 14 of Set 11 |
# Processing kafue Record 15 of Set 11 |
# Processing bonthe Record 16 of Set 11 |
# Processing la libertad Record 17 of Set 11 |
# Processing lieksa Record 18 of Set 11 |
# Processing rajshahi Record 19 of Set 11 |
# Processing serov Record 20 of Set 11 |
# Processing houma Record 21 of Set 11 |
# Processing nabire Record 22 of Set 11 |
# Processing husavik Record 23 of Set 11 |
# Processing ganzhou Record 24 of Set 11 |
# Processing svatove Record 25 of Set 11 |
# Processing fukue Record 26 of Set 11 |
# Processing santa rosa Record 27 of Set 11 |
# Processing barra Record 28 of Set 11 |
# Processing sile Record 29 of Set 11 |
# Processing silifke Record 30 of Set 11 |
# Processing hovd Record 31 of Set 11 |
# Processing bonavista Record 32 of Set 11 |
# Processing new waterford Record 33 of Set 11 |
# Processing zlynka Record 34 of Set 11 |
# Processing champasak Record 35 of Set 11 |
# Processing cherskiy Record 36 of Set 11 |
# Processing solnechnyy Record 37 of Set 11 |
# Processing samusu Record 38 of Set 11 |
# samusu not found. Skipping------------------------------
# Processing zhongshu Record 39 of Set 11 |
# Processing maloshuyka Record 40 of Set 11 |
# maloshuyka not found. Skipping------------------------------
# Processing irgakly Record 41 of Set 11 |
# Processing geraldton Record 42 of Set 11 |
# Processing chokwe Record 43 of Set 11 |
# Processing yulara Record 44 of Set 11 |
# Processing port augusta Record 45 of Set 11 |
# Processing ghanzi Record 46 of Set 11 |
# Processing nemuro Record 47 of Set 11 |
# Processing zilair Record 48 of Set 11 |
# Processing nantucket Record 49 of Set 11 |
# Processing axim Record 50 of Set 11 |
# Processing gualaquiza Record 0 of Set 12 |
# Processing polunochnoye Record 1 of Set 12 |
# Processing lata Record 2 of Set 12 |
# Processing santa maria da vitoria Record 3 of Set 12 |
# Processing isangel Record 4 of Set 12 |
# Processing winchester Record 5 of Set 12 |
# Processing kuusankoski Record 6 of Set 12 |
# Processing varkkallai Record 7 of Set 12 |
# Processing waingapu Record 8 of Set 12 |
# Processing caravelas Record 9 of Set 12 |
# Processing galle Record 10 of Set 12 |
# Processing murchison Record 11 of Set 12 |
# Processing banda aceh Record 12 of Set 12 |
# Processing lavrentiya Record 13 of Set 12 |
# Processing manggar Record 14 of Set 12 |
# Processing camacha Record 15 of Set 12 |
# Processing kaputa Record 16 of Set 12 |
# Processing matagami Record 17 of Set 12 |
# Processing lushunkou Record 18 of Set 12 |
# lushunkou not found. Skipping------------------------------
# Processing santa maria Record 19 of Set 12 |
# Processing byron bay Record 20 of Set 12 |
# Processing pangnirtung Record 21 of Set 12 |
# Processing poya Record 22 of Set 12 |
# Processing kloulklubed Record 23 of Set 12 |
# Processing guarapari Record 24 of Set 12 |
# Processing rapid valley Record 25 of Set 12 |
# Processing sarkand Record 26 of Set 12 |
# Processing lao cai Record 27 of Set 12 |
# Processing makung Record 28 of Set 12 |
# makung not found. Skipping------------------------------
# Processing sibu Record 29 of Set 12 |
# Processing tabory Record 30 of Set 12 |
# Processing palabuhanratu Record 31 of Set 12 |
# palabuhanratu not found. Skipping------------------------------
# Processing erzin Record 32 of Set 12 |
# Processing tumannyy Record 33 of Set 12 |
# tumannyy not found. Skipping------------------------------
# Processing gambela Record 34 of Set 12 |
# Processing washington Record 35 of Set 12 |
# Processing bandarbeyla Record 36 of Set 12 |
# Processing novorzhev Record 37 of Set 12 |
# Processing wuxue Record 38 of Set 12 |
# Processing tres arroyos Record 39 of Set 12 |
# Processing port hardy Record 40 of Set 12 |
# Processing palembang Record 41 of Set 12 |
# Processing dabola Record 42 of Set 12 |
# Processing parabel Record 43 of Set 12 |
# Processing sisimiut Record 44 of Set 12 |
# Processing strezhevoy Record 45 of Set 12 |
# Processing abu dhabi Record 46 of Set 12 |
# Processing grand-lahou Record 47 of Set 12 |
# Processing ngunguru Record 48 of Set 12 |
# Processing kaka Record 49 of Set 12 |
# Processing mae sai Record 50 of Set 12 |
# Processing trelew Record 0 of Set 13 |
# Processing sosva Record 1 of Set 13 |
# Processing obo Record 2 of Set 13 |
# Processing huarmey Record 3 of Set 13 |
# Processing qorveh Record 4 of Set 13 |

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#use variables from above to create dictionary 
city_data = {'City' : name,
                  'Lat' : lat,
                  'Lng' : lon,
                  'Max Temp' : max_temp,
                  'Humidity' : humidity,
                  'Cloudiness' : coludiness,
                  'Wind Speed' : wind_speed,
                  'Date' : date}
#convert dictionary to data frame
city_data_df = pd.DataFrame(city_data)
#store csv for use on part two of project
city_data_df.to_csv("../output_data/city_data_df.csv", index=False, header=True)
#check for correct amount of cities for review
len(city_data_df)
# Out:
# 560

# %%
# use .describe to statistically show Data Frame
city_data_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  560.000000  560.000000  560.000000  560.000000  560.000000  560.000000
# mean    19.794939   22.701718   49.360268   72.221429   56.369643    8.125714
# std     33.617944   92.073226   33.365963   20.564508   40.684538    5.749130
# min    -54.800000 -175.200000  -50.800000    1.000000    0.000000    0.360000
# 25%     -9.460025  -57.768125   31.747500   62.000000    6.750000    3.672500
# 50%     24.355750   28.065700   60.835000   77.000000   75.000000    6.670000
# 75%     48.168650  102.334775   76.400000   87.000000   98.000000   11.500000
# max     78.218600  179.316700  105.870000  100.000000  100.000000   32.210000
#
#                Date
# count  5.600000e+02
# mean   1.611516e+09
# std    3.017204e+02
# min    1.611516e+09
# 25%    1.611516e+09
# 50%    1.611517e+09
# 75%    1.611517e+09
# max    1.611517e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
indices = city_data_df.index[city_data_df['Humidity'] >= 100].tolist()
print(indices)
# Out:
# [34, 52, 89, 169, 204, 207, 260, 263, 288, 324, 422, 471, 493, 514, 544, 554]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# indices with humidity >=100 to drop
rows = city_data_df.index[indices]
# new dataframe with rows dropped
clean_city_data = city_data_df.drop(rows, inplace=True)
#clean_city_data.reset_index

# %%
#check for total cities after removing 100%+ humididty cities
clean_city_data = city_data_df
len(clean_city_data)
# Out:
# 544

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
dataTypeSeries = clean_city_data.dtypes
print(dataTypeSeries)

# %%
# setting plot and formatting
clean_city_data.plot(kind="scatter", x="Lat", y="Max Temp", marker="o", s=40, facecolors="red", 
                     edgecolors="black", grid=True, title="City Latitude vs. Max Temperature")
# set x axis title
plt.xlabel('Latitude')
# set y axis title
plt.ylabel('Max Temperature (F)')
#save plot as png
plt.savefig("../output_data/Latitude_vs_Max_Temp.png")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-6dc7777842b5> in <module>
# ----> 1 datetime.today()
#
# AttributeError: module 'datetime' has no attribute 'today'

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# setting plot and formatting
clean_city_data.plot(kind="scatter", x="Lat", y="Humidity", marker="o", s=40, facecolors="red", 
                     edgecolors="black", grid=True, title="City Latitude vs. Humidity")
# set x axis title
plt.xlabel('Latitude')
# set y axis title
plt.ylabel('Humidity')
#save plot as png
plt.savefig("../output_data/Latitude_vs_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# setting plot and formatting
clean_city_data.plot(kind="scatter", x="Lat", y="Cloudiness", marker="o", s=40, facecolors="red", 
                     edgecolors="black", grid=True, title="City Latitude vs. Cloudiness")
# set x axis title
plt.xlabel('Latitude')
# set y axis title
plt.ylabel('Cloudiness (%)')
#save plot as png
plt.savefig("../output_data/Latitude_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# setting plot and formatting
clean_city_data.plot(kind="scatter", x="Lat", y="Wind Speed", marker="o", s=40, facecolors="red", 
                     edgecolors="black", grid=True, title="City Latitude vs. Wind Speed")
# set x axis title
plt.xlabel('Latitude')
# set y axis title
plt.ylabel('Wind Speed (MPH)')
#save plot as png
plt.savefig("../output_data/Latitude_vs_Wind_Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# new df per hemisphere
north = clean_city_data.loc[clean_city_data['Lat']>0]
south = clean_city_data.loc[clean_city_data['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = north['Lat']
y_values = north['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# create plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
#add line equation to plot
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
# set x axis title
plt.xlabel('Latitude')
# set y axis title
plt.ylabel('Max Temp')
# displays r value
print(f"The r-squared is: {rvalue**2}")
#save plot as png
plt.savefig("../output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

plt.show()
# Out:
# The r-squared is: 0.7350280296089514

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
# axis values
x_values = south['Lat']
y_values = south['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# create plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# add line equation
plt.annotate(line_eq,(-10,60),fontsize=15,color="red")
# set x axis title
plt.xlabel('Latitude')
# set y axis title
plt.ylabel('Max Temp')
# print r value 
print(f"The r-squared is: {rvalue**2}")
#save plot as png
plt.savefig("../output_data/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.2002958689175195

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
# axis values
x_values = north['Lat']
y_values = north['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# creating plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# add line equation to plot
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
# setting x axis title
plt.xlabel('Latitude')
# setting y axis title
plt.ylabel('Humidity')
# displays r value
print(f"The r-squared is: {rvalue**2}")
#save plot as png
plt.savefig("../output_data/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.15042929186754764

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
# axis values
x_values = south['Lat']
y_values = south['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# creating plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# add line equation to plot
plt.annotate(line_eq,(-30,30),fontsize=15,color="red")
# setting x axis title
plt.xlabel('Latitude')
# setting y axis title
plt.ylabel('Humidity')
# displays r value
print(f"The r-squared is: {rvalue**2}")
#save plot as png
plt.savefig("../output_data/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.07364341403763591

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
# axis values
x_values = north['Lat']
y_values = north['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# creating plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# add line equation to plot
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
# setting x axis title
plt.xlabel('Latitude')
# setting y axis title
plt.ylabel('Cloudiness')
# displays r value
print(f"The r-squared is: {rvalue**2}")
#save plot as png
plt.savefig("../output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.04289047360662926

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
# axis values
x_values = south['Lat']
y_values = south['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# creating plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# add line equation to plot
plt.annotate(line_eq,(-30,30),fontsize=15,color="red")
# setting x axis title
plt.xlabel('Latitude')
# setting y axis title
plt.ylabel('Cloudiness')
# displays r value
print(f"The r-squared is: {rvalue**2}")
#save plot as png
plt.savefig("../output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.06755477760545057

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
# axis values
x_values = north['Lat']
y_values = north['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# creating plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# add line equation to plot
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
# setting x axis title
plt.xlabel('Latitude')
# setting y axis title
plt.ylabel('Wind Speed')
# displays r value
print(f"The r-squared is: {rvalue**2}")
#save plot as png
plt.savefig("../output_data/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.004264993389508723

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
# axis values
x_values = south['Lat']
y_values = south['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# creating plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# add line equation to plot
plt.annotate(line_eq,(-30,30),fontsize=15,color="red")
# setting x axis title
plt.xlabel('Latitude')
# setting y axis title
plt.ylabel('Wind Speed')
# displays r value
print(f"The r-squared is: {rvalue**2}")
#save plot as png
plt.savefig("../output_data/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.09782216512846884
