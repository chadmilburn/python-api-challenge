# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)


#print(weather_api_key)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#url
url = "http://api.openweathermap.org/data/2.5/weather?"
#api key loaded from api keys file
api_key = weather_api_key
temp_unit = "imperial"

# empty list to fill with API Call Data
name = []
lat = []
lon = []
max_temp = []
humidity = []
coludiness = []
wind_speed = []
country = []
date = []

# varibles for orginizing cities into sets of 50
records = 0
sets = 1

# query url
#query_url = (f'{url}appid={api_key}&units={temp_unit}&q={city_name}')
#query_url = "api.openweathermap.org/data/2.5/weather?" + city +"&appid=" + api_key

#working response link
#response = requests.get((f'{url}appid={api_key}&units={temp_unit}&q={city_name}')).json()

#print(response)

#print(json.dumps(response, indent=4, sort_keys=True))
# print(response['name'])
# print(response['coord']['lat'])
# print(response['coord']['lon'])
# print(response['main']['temp_max'])
# print(response['main']['humidity'])
# print(response['clouds']['all'])
# print(response['wind']['speed'])
# print(response['sys']['country'])
# print(response['dt'])


print('Beginning Data Retrieval')
print('---------------------------------------------------') 
# loop thorugh cities list to get weather data
for city in cities:
    #dynamic url from cities list
    new_url = (f'{url}appid={api_key}&units={temp_unit}&q={city}')
    #url response data in json format
    response = requests.get(new_url).json()
    #print(response)
    # organizing data in sets
    if records < 50:
         records = records + 1
    else:
         sets = sets + 1
         records = 0
    #print to watch loop work
    print(f'Processing {city} Record {records} of Set {sets} |')
    try:
        name.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        coludiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        #print(response)
    except KeyError:
        
        print(f'{city} not found. Skipping------------------------------')
# Out:
# Beginning Data Retrieval
# ---------------------------------------------------
# Processing kununurra Record 1 of Set 1 |
# Processing punta arenas Record 2 of Set 1 |
# Processing busselton Record 3 of Set 1 |
# Processing antofagasta Record 4 of Set 1 |
# Processing chara Record 5 of Set 1 |
# Processing kenai Record 6 of Set 1 |
# Processing bilma Record 7 of Set 1 |
# Processing sao filipe Record 8 of Set 1 |
# Processing tshikapa Record 9 of Set 1 |
# Processing new norfolk Record 10 of Set 1 |
# Processing cidreira Record 11 of Set 1 |
# Processing vidim Record 12 of Set 1 |
# Processing hermanus Record 13 of Set 1 |
# Processing bolungarvik Record 14 of Set 1 |
# bolungarvik not found. Skipping------------------------------
# Processing straumen Record 15 of Set 1 |
# Processing saint-joseph Record 16 of Set 1 |
# Processing illoqqortoormiut Record 17 of Set 1 |
# illoqqortoormiut not found. Skipping------------------------------
# Processing nizhneyansk Record 18 of Set 1 |
# nizhneyansk not found. Skipping------------------------------
# Processing hobart Record 19 of Set 1 |
# Processing nizwa Record 20 of Set 1 |
# Processing vaini Record 21 of Set 1 |
# Processing dikson Record 22 of Set 1 |
# Processing airai Record 23 of Set 1 |
# Processing ushuaia Record 24 of Set 1 |
# Processing ojinaga Record 25 of Set 1 |
# Processing tazovskiy Record 26 of Set 1 |
# Processing souillac Record 27 of Set 1 |
# Processing qaanaaq Record 28 of Set 1 |
# Processing severo-kurilsk Record 29 of Set 1 |
# Processing dimbokro Record 30 of Set 1 |
# Processing mataura Record 31 of Set 1 |
# Processing grand gaube Record 32 of Set 1 |
# Processing fare Record 33 of Set 1 |
# Processing batemans bay Record 34 of Set 1 |
# Processing aklavik Record 35 of Set 1 |
# Processing ixtapa Record 36 of Set 1 |
# Processing omboue Record 37 of Set 1 |
# Processing uray Record 38 of Set 1 |
# Processing seymchan Record 39 of Set 1 |
# Processing atuona Record 40 of Set 1 |
# Processing jamestown Record 41 of Set 1 |
# Processing iqaluit Record 42 of Set 1 |
# Processing cabo san lucas Record 43 of Set 1 |
# Processing ilulissat Record 44 of Set 1 |
# Processing aykhal Record 45 of Set 1 |
# Processing albany Record 46 of Set 1 |
# Processing hithadhoo Record 47 of Set 1 |
# Processing padang Record 48 of Set 1 |
# Processing butaritari Record 49 of Set 1 |
# Processing dukat Record 50 of Set 1 |
# Processing umm kaddadah Record 0 of Set 2 |
# Processing yellowknife Record 1 of Set 2 |
# Processing krasnoarmeysk Record 2 of Set 2 |
# Processing san carlos de bariloche Record 3 of Set 2 |
# Processing rikitea Record 4 of Set 2 |
# Processing lethem Record 5 of Set 2 |
# Processing mys shmidta Record 6 of Set 2 |
# mys shmidta not found. Skipping------------------------------
# Processing norman wells Record 7 of Set 2 |
# Processing bluff Record 8 of Set 2 |
# Processing atar Record 9 of Set 2 |
# Processing kuche Record 10 of Set 2 |
# kuche not found. Skipping------------------------------
# Processing narsaq Record 11 of Set 2 |
# Processing saint anthony Record 12 of Set 2 |
# Processing ahipara Record 13 of Set 2 |
# Processing upernavik Record 14 of Set 2 |
# Processing bilibino Record 15 of Set 2 |
# Processing aksu Record 16 of Set 2 |
# Processing mahebourg Record 17 of Set 2 |
# Processing vaitupu Record 18 of Set 2 |
# vaitupu not found. Skipping------------------------------
# Processing araouane Record 19 of Set 2 |
# Processing ponta delgada Record 20 of Set 2 |
# Processing sitka Record 21 of Set 2 |
# Processing digora Record 22 of Set 2 |
# Processing barrow Record 23 of Set 2 |
# Processing tuktoyaktuk Record 24 of Set 2 |
# Processing fort nelson Record 25 of Set 2 |
# Processing san patricio Record 26 of Set 2 |
# Processing hilo Record 27 of Set 2 |
# Processing anar darreh Record 28 of Set 2 |
# anar darreh not found. Skipping------------------------------
# Processing jacareacanga Record 29 of Set 2 |
# Processing kavali Record 30 of Set 2 |
# Processing chokurdakh Record 31 of Set 2 |
# Processing port elizabeth Record 32 of Set 2 |
# Processing bonthe Record 33 of Set 2 |
# Processing gorkovskoye Record 34 of Set 2 |
# gorkovskoye not found. Skipping------------------------------
# Processing cape town Record 35 of Set 2 |
# Processing samusu Record 36 of Set 2 |
# samusu not found. Skipping------------------------------
# Processing tiksi Record 37 of Set 2 |
# Processing namie Record 38 of Set 2 |
# Processing kampong chhnang Record 39 of Set 2 |
# Processing hasaki Record 40 of Set 2 |
# Processing port hedland Record 41 of Set 2 |
# Processing chauk Record 42 of Set 2 |
# Processing tasiilaq Record 43 of Set 2 |
# Processing aitape Record 44 of Set 2 |
# Processing tukrah Record 45 of Set 2 |
# Processing ponta do sol Record 46 of Set 2 |
# Processing taolanaro Record 47 of Set 2 |
# taolanaro not found. Skipping------------------------------
# Processing tilichiki Record 48 of Set 2 |
# Processing kodiak Record 49 of Set 2 |
# Processing beringovskiy Record 50 of Set 2 |
# Processing kanchipuram Record 0 of Set 3 |
# Processing kapaa Record 1 of Set 3 |
# Processing constitucion Record 2 of Set 3 |
# Processing lockport Record 3 of Set 3 |
# Processing dickinson Record 4 of Set 3 |
# Processing kalmunai Record 5 of Set 3 |
# Processing chuy Record 6 of Set 3 |
# Processing nikolskoye Record 7 of Set 3 |
# Processing grand river south east Record 8 of Set 3 |
# grand river south east not found. Skipping------------------------------
# Processing avarua Record 9 of Set 3 |
# Processing shu Record 10 of Set 3 |
# Processing paamiut Record 11 of Set 3 |
# Processing cabedelo Record 12 of Set 3 |
# Processing morondava Record 13 of Set 3 |
# Processing riachao das neves Record 14 of Set 3 |
# Processing mehamn Record 15 of Set 3 |
# Processing hambantota Record 16 of Set 3 |
# Processing hamilton Record 17 of Set 3 |
# Processing saint-philippe Record 18 of Set 3 |
# Processing praia da vitoria Record 19 of Set 3 |
# Processing saleaula Record 20 of Set 3 |
# saleaula not found. Skipping------------------------------
# Processing leshukonskoye Record 21 of Set 3 |
# Processing thompson Record 22 of Set 3 |
# Processing umm lajj Record 23 of Set 3 |
# Processing fairbanks Record 24 of Set 3 |
# Processing asyut Record 25 of Set 3 |
# Processing rocha Record 26 of Set 3 |
# Processing tomari Record 27 of Set 3 |
# Processing ancud Record 28 of Set 3 |
# Processing poum Record 29 of Set 3 |
# Processing inuvik Record 30 of Set 3 |
# Processing yar-sale Record 31 of Set 3 |
# Processing vostok Record 32 of Set 3 |
# Processing mabaruma Record 33 of Set 3 |
# Processing kashi Record 34 of Set 3 |
# Processing ondangwa Record 35 of Set 3 |
# Processing aktash Record 36 of Set 3 |
# Processing east london Record 37 of Set 3 |
# Processing tura Record 38 of Set 3 |
# Processing geraldton Record 39 of Set 3 |
# Processing honiara Record 40 of Set 3 |
# Processing guadix Record 41 of Set 3 |
# Processing darapidap Record 42 of Set 3 |
# Processing tsihombe Record 43 of Set 3 |
# tsihombe not found. Skipping------------------------------
# Processing mendahara Record 44 of Set 3 |
# mendahara not found. Skipping------------------------------
# Processing vila velha Record 45 of Set 3 |
# Processing saint george Record 46 of Set 3 |
# Processing sochi Record 47 of Set 3 |
# Processing charagua Record 48 of Set 3 |
# Processing savantvadi Record 49 of Set 3 |
# Processing yenagoa Record 50 of Set 3 |
# Processing sao joao da barra Record 0 of Set 4 |
# Processing sentyabrskiy Record 1 of Set 4 |
# sentyabrskiy not found. Skipping------------------------------
# Processing belushya guba Record 2 of Set 4 |
# belushya guba not found. Skipping------------------------------
# Processing tame Record 3 of Set 4 |
# Processing itarema Record 4 of Set 4 |
# Processing bordighera Record 5 of Set 4 |
# Processing skibbereen Record 6 of Set 4 |
# Processing saskylakh Record 7 of Set 4 |
# Processing meulaboh Record 8 of Set 4 |
# Processing kaitangata Record 9 of Set 4 |
# Processing oliver Record 10 of Set 4 |
# Processing cervo Record 11 of Set 4 |
# Processing matadi Record 12 of Set 4 |
# Processing clinton Record 13 of Set 4 |
# Processing senador jose porfirio Record 14 of Set 4 |
# Processing mrirt Record 15 of Set 4 |
# mrirt not found. Skipping------------------------------
# Processing karasburg Record 16 of Set 4 |
# Processing mindelo Record 17 of Set 4 |
# Processing yizheng Record 18 of Set 4 |
# Processing palmer Record 19 of Set 4 |
# Processing sinkat Record 20 of Set 4 |
# sinkat not found. Skipping------------------------------
# Processing kawana waters Record 21 of Set 4 |
# kawana waters not found. Skipping------------------------------
# Processing nueva gerona Record 22 of Set 4 |
# Processing port alfred Record 23 of Set 4 |
# Processing khatanga Record 24 of Set 4 |
# Processing bredasdorp Record 25 of Set 4 |
# Processing acari Record 26 of Set 4 |
# Processing barentsburg Record 27 of Set 4 |
# barentsburg not found. Skipping------------------------------
# Processing yulara Record 28 of Set 4 |
# Processing tuatapere Record 29 of Set 4 |
# Processing lompoc Record 30 of Set 4 |
# Processing okhotsk Record 31 of Set 4 |
# Processing puerto ayora Record 32 of Set 4 |
# Processing mar del plata Record 33 of Set 4 |
# Processing illapel Record 34 of Set 4 |
# Processing westport Record 35 of Set 4 |
# Processing coihaique Record 36 of Set 4 |
# Processing san cristobal Record 37 of Set 4 |
# Processing attawapiskat Record 38 of Set 4 |
# attawapiskat not found. Skipping------------------------------
# Processing laiwu Record 39 of Set 4 |
# Processing provideniya Record 40 of Set 4 |
# Processing puerto rondon Record 41 of Set 4 |
# Processing ostrovnoy Record 42 of Set 4 |
# Processing emporia Record 43 of Set 4 |
# Processing macia Record 44 of Set 4 |
# Processing broken hill Record 45 of Set 4 |
# Processing cranbrook Record 46 of Set 4 |
# Processing carnarvon Record 47 of Set 4 |
# Processing clyde river Record 48 of Set 4 |
# Processing ye Record 49 of Set 4 |
# ye not found. Skipping------------------------------
# Processing rawson Record 50 of Set 4 |
# Processing yevlax Record 0 of Set 5 |
# Processing faanui Record 1 of Set 5 |
# Processing marsala Record 2 of Set 5 |
# Processing saldanha Record 3 of Set 5 |
# Processing kirakira Record 4 of Set 5 |
# Processing zhaotong Record 5 of Set 5 |
# Processing topolobampo Record 6 of Set 5 |
# Processing notse Record 7 of Set 5 |
# Processing mapastepec Record 8 of Set 5 |
# Processing plettenberg bay Record 9 of Set 5 |
# Processing grand-santi Record 10 of Set 5 |
# Processing three hills Record 11 of Set 5 |
# Processing cherskiy Record 12 of Set 5 |
# Processing hurghada Record 13 of Set 5 |
# Processing guiratinga Record 14 of Set 5 |
# Processing owen sound Record 15 of Set 5 |
# Processing shenjiamen Record 16 of Set 5 |
# Processing longyearbyen Record 17 of Set 5 |
# Processing emerald Record 18 of Set 5 |
# Processing uslar Record 19 of Set 5 |
# Processing innisfail Record 20 of Set 5 |
# Processing mount isa Record 21 of Set 5 |
# Processing chifeng Record 22 of Set 5 |
# Processing esperance Record 23 of Set 5 |
# Processing deer lake Record 24 of Set 5 |
# Processing castro Record 25 of Set 5 |
# Processing hay river Record 26 of Set 5 |
# Processing qaqortoq Record 27 of Set 5 |
# Processing nemuro Record 28 of Set 5 |
# Processing bambous virieux Record 29 of Set 5 |
# Processing alofi Record 30 of Set 5 |
# Processing nieuw amsterdam Record 31 of Set 5 |
# Processing maldonado Record 32 of Set 5 |
# Processing hegang Record 33 of Set 5 |
# Processing sorong Record 34 of Set 5 |
# Processing harper Record 35 of Set 5 |
# Processing cottonwood Record 36 of Set 5 |
# Processing port blair Record 37 of Set 5 |
# Processing ramnagar Record 38 of Set 5 |
# Processing canon city Record 39 of Set 5 |
# Processing forbes Record 40 of Set 5 |
# Processing cap malheureux Record 41 of Set 5 |
# Processing bengkulu Record 42 of Set 5 |
# Processing dong xoai Record 43 of Set 5 |
# Processing berlevag Record 44 of Set 5 |
# Processing margate Record 45 of Set 5 |
# Processing fortuna Record 46 of Set 5 |
# Processing kawalu Record 47 of Set 5 |
# Processing port-cartier Record 48 of Set 5 |
# Processing anadyr Record 49 of Set 5 |
# Processing lebu Record 50 of Set 5 |
# Processing smithers Record 0 of Set 6 |
# Processing hofn Record 1 of Set 6 |
# Processing torbay Record 2 of Set 6 |
# Processing cascais Record 3 of Set 6 |
# Processing rokupr Record 4 of Set 6 |
# Processing mount vernon Record 5 of Set 6 |
# Processing horodnytsya Record 6 of Set 6 |
# Processing ihosy Record 7 of Set 6 |
# Processing guerrero negro Record 8 of Set 6 |
# Processing papar Record 9 of Set 6 |
# Processing rexburg Record 10 of Set 6 |
# Processing nadym Record 11 of Set 6 |
# Processing karratha Record 12 of Set 6 |
# Processing gizo Record 13 of Set 6 |
# Processing roma Record 14 of Set 6 |
# Processing richards bay Record 15 of Set 6 |
# Processing maple creek Record 16 of Set 6 |
# Processing alekseyevsk Record 17 of Set 6 |
# Processing huanren Record 18 of Set 6 |
# Processing kerteh Record 19 of Set 6 |
# kerteh not found. Skipping------------------------------
# Processing flinders Record 20 of Set 6 |
# Processing touros Record 21 of Set 6 |
# Processing chapais Record 22 of Set 6 |
# Processing half moon bay Record 23 of Set 6 |
# Processing marsh harbour Record 24 of Set 6 |
# Processing san quintin Record 25 of Set 6 |
# Processing lorengau Record 26 of Set 6 |
# Processing wau Record 27 of Set 6 |
# Processing northam Record 28 of Set 6 |
# Processing djambala Record 29 of Set 6 |
# Processing henties bay Record 30 of Set 6 |
# Processing kamenka Record 31 of Set 6 |
# Processing nanortalik Record 32 of Set 6 |
# Processing gemona Record 33 of Set 6 |
# Processing tromso Record 34 of Set 6 |
# Processing dubrovnik Record 35 of Set 6 |
# Processing kameshkovo Record 36 of Set 6 |
# Processing itoman Record 37 of Set 6 |
# Processing roald Record 38 of Set 6 |
# Processing aanekoski Record 39 of Set 6 |
# Processing korla Record 40 of Set 6 |
# Processing pisco Record 41 of Set 6 |
# Processing san ignacio de sabaneta Record 42 of Set 6 |
# san ignacio de sabaneta not found. Skipping------------------------------
# Processing sisimiut Record 43 of Set 6 |
# Processing husavik Record 44 of Set 6 |
# Processing laguna Record 45 of Set 6 |
# Processing patiala Record 46 of Set 6 |
# Processing mayo Record 47 of Set 6 |
# Processing namatanai Record 48 of Set 6 |
# Processing sampit Record 49 of Set 6 |
# Processing saint-francois Record 50 of Set 6 |
# Processing salalah Record 0 of Set 7 |
# Processing darovskoy Record 1 of Set 7 |
# Processing yaan Record 2 of Set 7 |
# Processing camacupa Record 3 of Set 7 |
# Processing bethel Record 4 of Set 7 |
# Processing bathsheba Record 5 of Set 7 |
# Processing lavrentiya Record 6 of Set 7 |
# Processing chunan Record 7 of Set 7 |
# Processing abapo Record 8 of Set 7 |
# Processing sundargarh Record 9 of Set 7 |
# Processing dublin Record 10 of Set 7 |
# Processing georgetown Record 11 of Set 7 |
# Processing elizabeth city Record 12 of Set 7 |
# Processing zlitan Record 13 of Set 7 |
# Processing jasper Record 14 of Set 7 |
# Processing kruisfontein Record 15 of Set 7 |
# Processing khatassy Record 16 of Set 7 |
# Processing sergeyevka Record 17 of Set 7 |
# Processing pevek Record 18 of Set 7 |
# Processing phan rang Record 19 of Set 7 |
# phan rang not found. Skipping------------------------------
# Processing coahuayana Record 20 of Set 7 |
# Processing port hawkesbury Record 21 of Set 7 |
# Processing loiza Record 22 of Set 7 |
# Processing puquio Record 23 of Set 7 |
# Processing kerrville Record 24 of Set 7 |
# Processing tongren Record 25 of Set 7 |
# Processing port macquarie Record 26 of Set 7 |
# Processing botwood Record 27 of Set 7 |
# Processing ribeira grande Record 28 of Set 7 |
# Processing amderma Record 29 of Set 7 |
# amderma not found. Skipping------------------------------
# Processing ust-tsilma Record 30 of Set 7 |
# Processing conil Record 31 of Set 7 |
# Processing ust-kuyga Record 32 of Set 7 |
# Processing svetlyy Record 33 of Set 7 |
# Processing malwan Record 34 of Set 7 |
# malwan not found. Skipping------------------------------
# Processing ziyang Record 35 of Set 7 |
# Processing petropavlovsk-kamchatskiy Record 36 of Set 7 |
# Processing oranjemund Record 37 of Set 7 |
# Processing unity Record 38 of Set 7 |
# Processing haibowan Record 39 of Set 7 |
# haibowan not found. Skipping------------------------------
# Processing sept-iles Record 40 of Set 7 |
# Processing caravelas Record 41 of Set 7 |
# Processing burnie Record 42 of Set 7 |
# Processing sapao Record 43 of Set 7 |
# sapao not found. Skipping------------------------------
# Processing kloulklubed Record 44 of Set 7 |
# Processing petrivka Record 45 of Set 7 |
# Processing jibuti Record 46 of Set 7 |
# Processing pemangkat Record 47 of Set 7 |
# Processing neiafu Record 48 of Set 7 |
# Processing iskateley Record 49 of Set 7 |
# Processing luderitz Record 50 of Set 7 |
# Processing hvammstangi Record 0 of Set 8 |
# hvammstangi not found. Skipping------------------------------
# Processing honningsvag Record 1 of Set 8 |
# Processing lata Record 2 of Set 8 |
# Processing turayf Record 3 of Set 8 |
# Processing benjamin constant Record 4 of Set 8 |
# Processing ahuimanu Record 5 of Set 8 |
# Processing pochutla Record 6 of Set 8 |
# Processing atherton Record 7 of Set 8 |
# Processing makinsk Record 8 of Set 8 |
# Processing arlit Record 9 of Set 8 |
# Processing palabuhanratu Record 10 of Set 8 |
# palabuhanratu not found. Skipping------------------------------
# Processing sarangani Record 11 of Set 8 |
# Processing caxito Record 12 of Set 8 |
# Processing pilar Record 13 of Set 8 |
# Processing hami Record 14 of Set 8 |
# Processing huilong Record 15 of Set 8 |
# Processing north bend Record 16 of Set 8 |
# Processing bardiyah Record 17 of Set 8 |
# Processing kaabong Record 18 of Set 8 |
# Processing sur Record 19 of Set 8 |
# Processing kahului Record 20 of Set 8 |
# Processing duma Record 21 of Set 8 |
# Processing wahran Record 22 of Set 8 |
# wahran not found. Skipping------------------------------
# Processing vardo Record 23 of Set 8 |
# Processing kadoma Record 24 of Set 8 |
# Processing ardmore Record 25 of Set 8 |
# Processing punta alta Record 26 of Set 8 |
# Processing maragogi Record 27 of Set 8 |
# Processing sabha Record 28 of Set 8 |
# Processing dingle Record 29 of Set 8 |
# Processing diego de almagro Record 30 of Set 8 |
# Processing tra vinh Record 31 of Set 8 |
# Processing oranjestad Record 32 of Set 8 |
# Processing dubbo Record 33 of Set 8 |
# Processing naryan-mar Record 34 of Set 8 |
# Processing sibolga Record 35 of Set 8 |
# Processing kavieng Record 36 of Set 8 |
# Processing avera Record 37 of Set 8 |
# Processing nouadhibou Record 38 of Set 8 |
# Processing olenegorsk Record 39 of Set 8 |
# Processing tumannyy Record 40 of Set 8 |
# tumannyy not found. Skipping------------------------------
# Processing altay Record 41 of Set 8 |
# Processing grindavik Record 42 of Set 8 |
# Processing bonavista Record 43 of Set 8 |
# Processing unye Record 44 of Set 8 |
# unye not found. Skipping------------------------------
# Processing amahai Record 45 of Set 8 |
# Processing gayny Record 46 of Set 8 |
# Processing lazarev Record 47 of Set 8 |
# Processing deh rawud Record 48 of Set 8 |
# deh rawud not found. Skipping------------------------------
# Processing akkermanovka Record 49 of Set 8 |
# Processing balakovo Record 50 of Set 8 |
# Processing fuxin Record 0 of Set 9 |
# Processing novokayakent Record 1 of Set 9 |
# Processing hagerstown Record 2 of Set 9 |
# Processing leningradskiy Record 3 of Set 9 |
# Processing nsanje Record 4 of Set 9 |
# Processing asahikawa Record 5 of Set 9 |
# Processing buraydah Record 6 of Set 9 |
# Processing namibe Record 7 of Set 9 |
# Processing puri Record 8 of Set 9 |
# Processing kupang Record 9 of Set 9 |
# Processing shebunino Record 10 of Set 9 |
# Processing adrian Record 11 of Set 9 |
# Processing sindgi Record 12 of Set 9 |
# Processing el real de santa maria Record 13 of Set 9 |
# Processing limoges Record 14 of Set 9 |
# Processing shelburne Record 15 of Set 9 |
# Processing caucaia Record 16 of Set 9 |
# Processing kidal Record 17 of Set 9 |
# Processing bandarbeyla Record 18 of Set 9 |
# Processing esna Record 19 of Set 9 |
# Processing mbarara Record 20 of Set 9 |
# Processing yangshan Record 21 of Set 9 |
# Processing safranbolu Record 22 of Set 9 |
# Processing astipalaia Record 23 of Set 9 |
# astipalaia not found. Skipping------------------------------
# Processing george town Record 24 of Set 9 |
# Processing colwyn bay Record 25 of Set 9 |
# Processing shimoda Record 26 of Set 9 |
# Processing ayan Record 27 of Set 9 |
# Processing arraial do cabo Record 28 of Set 9 |
# Processing ukiah Record 29 of Set 9 |
# Processing san pedro Record 30 of Set 9 |
# Processing verkhnyaya inta Record 31 of Set 9 |
# Processing arona Record 32 of Set 9 |
# Processing nantucket Record 33 of Set 9 |
# Processing mezen Record 34 of Set 9 |
# Processing talnakh Record 35 of Set 9 |
# Processing nome Record 36 of Set 9 |
# Processing mountain home Record 37 of Set 9 |
# Processing maumere Record 38 of Set 9 |
# Processing korsor Record 39 of Set 9 |
# Processing zhigansk Record 40 of Set 9 |
# Processing marystown Record 41 of Set 9 |
# Processing flin flon Record 42 of Set 9 |
# Processing yeppoon Record 43 of Set 9 |
# Processing tessalit Record 44 of Set 9 |
# Processing kabanjahe Record 45 of Set 9 |
# Processing kagoro Record 46 of Set 9 |
# Processing contamana Record 47 of Set 9 |
# Processing kaeo Record 48 of Set 9 |
# Processing olga Record 49 of Set 9 |
# Processing lircay Record 50 of Set 9 |
# Processing havre-saint-pierre Record 0 of Set 10 |
# Processing basco Record 1 of Set 10 |
# Processing saint-denis Record 2 of Set 10 |
# Processing necochea Record 3 of Set 10 |
# Processing dawson creek Record 4 of Set 10 |
# Processing gasa Record 5 of Set 10 |
# Processing port lincoln Record 6 of Set 10 |
# Processing katsuura Record 7 of Set 10 |
# Processing thetford mines Record 8 of Set 10 |
# Processing markova Record 9 of Set 10 |
# Processing tautira Record 10 of Set 10 |
# Processing conde Record 11 of Set 10 |
# Processing niquelandia Record 12 of Set 10 |
# Processing cadillac Record 13 of Set 10 |
# Processing baghdad Record 14 of Set 10 |
# Processing rewari Record 15 of Set 10 |
# Processing tianjin Record 16 of Set 10 |
# Processing mercedes Record 17 of Set 10 |
# Processing tutoia Record 18 of Set 10 |
# Processing kota belud Record 19 of Set 10 |
# Processing nizhniy ingash Record 20 of Set 10 |
# Processing xining Record 21 of Set 10 |
# Processing zolotinka Record 22 of Set 10 |
# zolotinka not found. Skipping------------------------------
# Processing zarubino Record 23 of Set 10 |
# Processing doha Record 24 of Set 10 |
# Processing alcantara Record 25 of Set 10 |
# Processing da nang Record 26 of Set 10 |
# Processing rock sound Record 27 of Set 10 |
# Processing gornouralskiy Record 28 of Set 10 |
# gornouralskiy not found. Skipping------------------------------
# Processing alice springs Record 29 of Set 10 |
# Processing dongning Record 30 of Set 10 |
# Processing pangnirtung Record 31 of Set 10 |
# Processing kijang Record 32 of Set 10 |
# Processing havelock Record 33 of Set 10 |
# Processing horsham Record 34 of Set 10 |
# Processing de aar Record 35 of Set 10 |
# Processing nagato Record 36 of Set 10 |
# Processing gwadar Record 37 of Set 10 |
# Processing katangli Record 38 of Set 10 |
# Processing vila Record 39 of Set 10 |
# Processing carlos antonio lopez Record 40 of Set 10 |
# Processing xinzhi Record 41 of Set 10 |
# Processing lagoa Record 42 of Set 10 |
# Processing pedernales Record 43 of Set 10 |
# Processing yeniseysk Record 44 of Set 10 |
# Processing ornskoldsvik Record 45 of Set 10 |
# Processing canavieiras Record 46 of Set 10 |
# Processing natal Record 47 of Set 10 |
# Processing ust-kut Record 48 of Set 10 |
# Processing le mars Record 49 of Set 10 |
# Processing teahupoo Record 50 of Set 10 |
# Processing kamaishi Record 0 of Set 11 |
# Processing bayamo Record 1 of Set 11 |
# Processing santa paula Record 2 of Set 11 |
# Processing daru Record 3 of Set 11 |
# Processing gamboma Record 4 of Set 11 |
# Processing rancho palos verdes Record 5 of Set 11 |
# Processing boa vista Record 6 of Set 11 |
# Processing baturaja Record 7 of Set 11 |
# Processing lannion Record 8 of Set 11 |
# Processing hazaribag Record 9 of Set 11 |
# Processing san fernando Record 10 of Set 11 |
# Processing arak Record 11 of Set 11 |
# Processing quchan Record 12 of Set 11 |
# Processing najran Record 13 of Set 11 |
# Processing nanchong Record 14 of Set 11 |
# Processing kuri Record 15 of Set 11 |
# Processing cockburn town Record 16 of Set 11 |
# Processing civitavecchia Record 17 of Set 11 |
# Processing kegayli Record 18 of Set 11 |
# kegayli not found. Skipping------------------------------
# Processing kuito Record 19 of Set 11 |
# Processing slave lake Record 20 of Set 11 |
# Processing sumenep Record 21 of Set 11 |
# Processing jardim Record 22 of Set 11 |
# Processing sambava Record 23 of Set 11 |
# Processing inverell Record 24 of Set 11 |
# Processing whitehorse Record 25 of Set 11 |
# Processing zhuhai Record 26 of Set 11 |
# Processing halalo Record 27 of Set 11 |
# halalo not found. Skipping------------------------------
# Processing nyimba Record 28 of Set 11 |
# Processing kholodnyy Record 29 of Set 11 |
# Processing outlook Record 30 of Set 11 |
# Processing liverpool Record 31 of Set 11 |
# Processing villamontes Record 32 of Set 11 |
# Processing rebrikha Record 33 of Set 11 |
# Processing bataraza Record 34 of Set 11 |
# bataraza not found. Skipping------------------------------
# Processing stokmarknes Record 35 of Set 11 |
# Processing crixas Record 36 of Set 11 |
# Processing robertsport Record 37 of Set 11 |
# Processing vagay Record 38 of Set 11 |
# Processing yerbogachen Record 39 of Set 11 |
# Processing laje Record 40 of Set 11 |
# Processing aflu Record 41 of Set 11 |
# aflu not found. Skipping------------------------------
# Processing balasesti Record 42 of Set 11 |
# Processing los llanos de aridane Record 43 of Set 11 |
# Processing karczew Record 44 of Set 11 |
# Processing reggio di calabria Record 45 of Set 11 |
# Processing salamanca Record 46 of Set 11 |
# Processing iranshahr Record 47 of Set 11 |
# Processing muros Record 48 of Set 11 |
# Processing portland Record 49 of Set 11 |
# Processing monrovia Record 50 of Set 11 |
# Processing jijiga Record 0 of Set 12 |
# Processing sakaiminato Record 1 of Set 12 |
# Processing tulum Record 2 of Set 12 |
# Processing raymond Record 3 of Set 12 |
# Processing hun Record 4 of Set 12 |
# Processing maridi Record 5 of Set 12 |
# Processing quatre cocos Record 6 of Set 12 |
# Processing patti Record 7 of Set 12 |
# Processing ouesso Record 8 of Set 12 |
# Processing komsomolskiy Record 9 of Set 12 |
# Processing zaraza Record 10 of Set 12 |
# Processing zaltan Record 11 of Set 12 |
# Processing buala Record 12 of Set 12 |
# Processing karaul Record 13 of Set 12 |
# karaul not found. Skipping------------------------------
# Processing gat Record 14 of Set 12 |
# Processing zhanatas Record 15 of Set 12 |
# zhanatas not found. Skipping------------------------------
# Processing sabang Record 16 of Set 12 |
# Processing sao raimundo nonato Record 17 of Set 12 |
# Processing noumea Record 18 of Set 12 |
# Processing saint-georges Record 19 of Set 12 |
# Processing qianguo Record 20 of Set 12 |
# Processing srednekolymsk Record 21 of Set 12 |
# Processing lavumisa Record 22 of Set 12 |
# Processing iralaya Record 23 of Set 12 |
# Processing podgorodnyaya pokrovka Record 24 of Set 12 |
# Processing cloppenburg Record 25 of Set 12 |
# Processing boddam Record 26 of Set 12 |
# Processing kishanganj Record 27 of Set 12 |
# Processing yazman Record 28 of Set 12 |
# Processing zarand Record 29 of Set 12 |
# Processing denpasar Record 30 of Set 12 |
# Processing champerico Record 31 of Set 12 |
# Processing chabahar Record 32 of Set 12 |
# Processing saint-augustin Record 33 of Set 12 |
# Processing camopi Record 34 of Set 12 |
# Processing ghanzi Record 35 of Set 12 |
# Processing dunmore east Record 36 of Set 12 |
# Processing mitzic Record 37 of Set 12 |
# Processing koumac Record 38 of Set 12 |
# Processing port-de-paix Record 39 of Set 12 |
# port-de-paix not found. Skipping------------------------------
# Processing victoria Record 40 of Set 12 |
# Processing ushtobe Record 41 of Set 12 |
# Processing gimli Record 42 of Set 12 |
# Processing itaituba Record 43 of Set 12 |
# Processing nizhnyaya poyma Record 44 of Set 12 |
# Processing kadykchan Record 45 of Set 12 |
# kadykchan not found. Skipping------------------------------
# Processing dauphin Record 46 of Set 12 |
# Processing sucre Record 47 of Set 12 |
# Processing dunedin Record 48 of Set 12 |
# Processing shakawe Record 49 of Set 12 |
# Processing kinablangan Record 50 of Set 12 |

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#use variables from above to create dictionary 
city_data = {'City' : name,
                  'Lat' : lat,
                  'Lng' : lon,
                  'Max Temp' : max_temp,
                  'Humidity' : humidity,
                  'Cloudiness' : coludiness,
                  'Wind Speed' : wind_speed,
                  'Date' : date}
#convert dictionary to data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv("city_data_df.csv", index=True, header=True)
city_data_df.head()
len(city_data_df)
# Out:
# 565

# %%
# use .describe to statistically show Data Frame
city_data_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    21.574756   16.362416   48.648124   72.203540   52.939823    8.262212
# std     32.683170   91.157628   33.500370   19.460343   41.017466    5.979128
# min    -54.800000 -175.200000  -59.800000   15.000000    0.000000    0.130000
# 25%     -5.795000  -63.466700   28.000000   63.000000    1.000000    3.980000
# 50%     27.316700   18.092200   57.160000   77.000000   65.000000    6.870000
# 75%     48.649900  100.335400   77.000000   87.000000   94.000000   11.180000
# max     78.218600  179.316700   97.020000  100.000000  100.000000   34.270000
#
#                Date
# count  5.650000e+02
# mean   1.611433e+09
# std    8.266176e+01
# min    1.611432e+09
# 25%    1.611433e+09
# 50%    1.611433e+09
# 75%    1.611433e+09
# max    1.611433e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
indices = city_data_df.index[city_data_df['Humidity'] >= 100].tolist()
print(indices)
# Out:
# [0, 19, 81, 106, 142, 235, 321, 416, 465]

# %%
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ratnagiri  16.9833   73.3000     77.14        76          31
# 1           Ushuaia -54.8000  -68.3000     50.00        57          75
# 2           Isangel -19.5500  169.2667     77.58        87         100
# 3         Busselton -33.6500  115.3333     62.31        86           4
# 4         Cape Town -33.9258   18.4232     78.80        47          20
# 5          Portland  45.5234 -122.6762     33.01        86          20
# 6            Barrow  71.2906 -156.7887      6.80        78          75
# 7    Port Elizabeth -33.9180   25.5701     75.20        73          75
# 8         Dyurtyuli  55.4911   54.8688      7.00        94         100
# 9       Clyde River  70.4692  -68.5914     -5.80        84          90
# 10             Tauá  -5.9667  -40.3000     87.67        42         100
# 11            Vaini -21.2000 -175.2000     75.20       100          75
# 12          Zhangye  38.9342  100.4517     28.18        74         100
# 13         Cherskiy  68.7500  161.3000    -26.91        85         100
# 14            Sitka  57.0531 -135.3300     37.40        93          90
# 15             Lebu -37.6167  -73.6500     65.12        79          42
# 16            Muros  42.7762   -9.0603     59.00        87         100
# 17         Barranca -10.7500  -77.7667     76.08        63          78
# 18             Esim   4.8699   -2.2405     83.79        67          49
# 19      Yerbogachën  61.2767  108.0108    -53.39        73          48
# 20   Saint-Philippe -21.3585   55.7679     86.00        66          50
# 21  Severo-Kuril'sk  50.6789  156.1250     24.24        94          99
# 22     Punta Arenas -53.1500  -70.9167     57.20        47           0
# 23          Te Anau -45.4167  167.7167     49.84        75         100
# 24     Puerto Ayora  -0.7393  -90.3518     75.20        94          75
# 25     Longyearbyen  78.2186   15.6401      8.60        72           0
# 26         Hermanus -34.4187   19.2345     75.99        63           1
# 27       Butaritari   3.0707  172.7902     78.94        84           0
# 28           Torbay  47.6666  -52.7314     25.00       100          90
# 29          Rikitea -23.1203 -134.9692     78.19        67          13
#
#     Wind Speed        Date
# 0         8.79  1611412292
# 1        10.36  1611412248
# 2         8.90  1611412292
# 3         3.60  1611412292
# 4        12.66  1611412171
# 5         0.25  1611412214
# 6        20.71  1611412040
# 7        28.77  1611412293
# 8        12.21  1611412288
# 9         3.44  1611412293
# 10       10.29  1611412293
# 11        3.44  1611412293
# 12       17.40  1611412293
# 13        6.35  1611412294
# 14        3.44  1611412294
# 15       18.81  1611412294
# 16        5.01  1611412294
# 17        8.12  1611412294
# 18       11.32  1611412294
# 19        0.78  1611412294
# 20        4.61  1611412294
# 21       29.30  1611412295
# 22       31.07  1611412035
# 23        8.12  1611412296
# 24       10.36  1611412032
# 25       11.50  1611412296
# 26       11.99  1611412186
# 27       10.29  1611412049
# 28       18.41  1611412043
# 29       10.74  1611412296

# %%
# indices with humidity >=100 to drop
rows = city_data_df.index[indices]
# new dataframe with rows dropped
clean_city_data = city_data_df.drop(rows, inplace=True)
#clean_city_data.reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-05bc7cbcd73b> in <module>
#       5 #clean_city_data.reset_index()
#       6
# ----> 7 clean_city_data.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
clean_city_data = city_data_df
#clean_city_data.head(15)
len(clean_city_data)
# Out:
# 556

# %%
clean_city_data.head(20)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1   Punta Arenas -53.1500  -70.9167     59.00        47           0
# 2      Busselton -33.6500  115.3333     61.00        88          38
# 3    Antofagasta -23.6500  -70.4000     73.99        73           0
# 4          Chara  56.9064  118.2631    -25.17        81          44
# 5          Kenai  60.5544 -151.2583     36.00        75          90
# 6          Bilma  18.6853   12.9164     61.65        26           0
# 7     São Filipe  14.8961  -24.4956     74.07        68          28
# 8       Tshikapa  -6.4167   20.8000     72.54        90         100
# 9    New Norfolk -42.7826  147.0587     57.00        75           5
# 10      Cidreira -30.1811  -50.2056     78.80        76           0
# 11         Vidim  56.4088  103.1106     -7.65        90         100
# 12      Hermanus -34.4187   19.2345     62.01        95          99
# 13      Straumen  63.8709   11.2999     32.00        93          75
# 14  Saint-Joseph -21.3667   55.6167     80.60        74           0
# 15        Hobart -42.8794  147.3294     57.00        94          40
# 16         Nizwá  22.9333   57.5333     55.53        58           0
# 17         Vaini -21.2000 -175.2000     78.80        94          75
# 18        Dikson  73.5069   80.5464    -16.96        90          95
# 20       Ushuaia -54.8000  -68.3000     60.80        41          75
# 21       Ojinaga  29.5667 -104.4167     66.20        42           1
#
#     Wind Speed        Date
# 1        29.93  1611432607
# 2         4.47  1611432311
# 3        13.80  1611432363
# 4         0.13  1611432361
# 5        21.85  1611432607
# 6         6.73  1611432607
# 7         7.09  1611432607
# 8         2.66  1611432607
# 9         2.53  1611432607
# 10       15.26  1611432607
# 11        2.48  1611432608
# 12        3.00  1611432608
# 13        5.44  1611432608
# 14        5.75  1611432608
# 15        5.75  1611432479
# 16        2.21  1611432375
# 17        4.61  1611432311
# 18        6.08  1611432608
# 20       10.58  1611432239
# 21        6.53  1611432609

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
dataTypeSeries = clean_city_data.dtypes
print(dataTypeSeries)
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Date            int64
# dtype: object

# %%
clean_city_data.plot(kind="scatter", x="Lat", y="Max Temp", marker="o", s=40, facecolors="red", 
                     edgecolors="black", grid=True, title="City Latitude vs. Max Temperature")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
clean_city_data.plot(kind="scatter", x="Lat", y="Humidity", marker="o", s=40, facecolors="red", 
                     edgecolors="black", grid=True, title="City Latitude vs. Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clean_city_data.plot(kind="scatter", x="Lat", y="Cloudiness", marker="o", s=40, facecolors="red", 
                     edgecolors="black", grid=True, title="City Latitude vs. Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
clean_city_data.plot(kind="scatter", x="Lat", y="Wind Speed", marker="o", s=40, facecolors="red", 
                     edgecolors="black", grid=True, title="City Latitude vs. Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# new df per hemisphere
north = clean_city_data.loc[clean_city_data['Lat']>0]
south = clean_city_data.loc[clean_city_data['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = north['Lat']
y_values = north['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7510964582844597

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = south['Lat']
y_values = south['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-10,60),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.19472633087778002

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = north['Lat']
y_values = north['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.10778572892361545

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south['Lat']
y_values = south['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.056294235606369425

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north['Lat']
y_values = north['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.02801190356672701

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south['Lat']
y_values = south['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.10516749344591392

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north['Lat']
y_values = north['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.005618258404647983

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south['Lat']
y_values = south['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09377845633078216
